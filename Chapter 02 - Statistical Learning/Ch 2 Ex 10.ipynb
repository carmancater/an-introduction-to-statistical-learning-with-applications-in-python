# %% [markdown]
# # Chapter 2: Exercise 10

# %% [markdown]
# **Import packages**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Part (a)
# **Load Boston data set**

# %%
os.chdir('C:/Users/carma/Documents/Python Projects/islp')
Boston = pd.read_csv('Boston.csv')

# %% [markdown]
# ## Part (b)
# **Description of rows and columns.**

# %%
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
Boston.shape
# Out:
# (506, 14)

# %% [markdown]
# We see there are 506 rows and 14 columns. The rows represent suburbs of Boston, MA. The column discriptions are as follows:
# - **crim:** per capita crime rate by town.
# - **zn:** proportion of residential land zoned for lots over 25,000 sq.ft.
# - **indus:** proportion of non-retail business acres per town.
# - **chas:** Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - **nox:** nitrogen oxides concentration (parts per 10 million).
# - **rm:** average number of rooms per dwelling.
# - **age:** proportion of owner-occupied units built prior to 1940.
# - **dis:** weighted mean of distances to five Boston employment centres.
# - **rad:** index of accessibility to radial highways.
# - **tax:** full-value property-tax rate per &dollar;10,000.
# - **ptratio:** pupil-teacher ratio by town.
# - **b:** 1000(Bk - 0.63)<sup>2</sup> where Bk is the proportion of blacks by town.
# - **lstat:** lower status of the population (percent).
# - **medv:** median value of owner-occupied homes in &dollar;1000s.

# %% [markdown]
# ## Part (c)
# **Pairwise scatterplots and observations.**

# %%
sns.set_theme(style='ticks')
sns.pairplot(Boston)

# %% [markdown]
# **Observations**
# - As crim increases medv decreases (As crim decreases medv increases).
# - As zn increases lstat decreases.
# - As dis increases zn increases.
# - As age increases zn decreases.
# - As indus increases medv decreases.
# - As indus increases lstat increases.
# - As dis decreases indus increases (As dis increases indus decreases).
# - As age increases crim increases.
# - As indus increases nox increases.
# - As zn increases indus decreases.
# - As nox increases medv decreases.
# - As nox increases lstat increases.
# - As dis decreases nox increases (As dis increases nox decreases).
# - As dis decreases crim increases (As dis increases crim decreases).
# - As age increases nox increases.
# - As nox increases crim increases.
# - As rm increases medv increases.
# - As rm increases lstat decreases (As lstat increases rm decreases).
# - As dis increases age decreases.
# - As dis increases rm increases.
# - As dis increases lstat decreases (As dis decreases lstat increases).
# - As lstat increases crim increases.
# - As lstat increases age increases.
# - As lstat increases medv decreases (As medv increases lstat decreases).
# - As ptratio increases medv decreases.

# %% [markdown]
# ## Part (d)
# **Associations to per capita crime rate (crim).**
#
# - As proportion of owner-occupied units built prior to 1940 (age) increases crim increases.
# - As weighted mean of distances to five Boston employment centres (dis) decreases crim increases (As dis increases crim decreases).
# - As lower status of the population (lstat) increases crim increases.
# - As crim increases median value of owner-occupied homes (medv) decreases (As crim decreases medv increases).

# %% [markdown]
# ## Part (e)
# **Suburbs of Boston with high crime rate, high tax rate, high pupil-teacher ratios. Range of predictors.**

# %% [markdown]
# **Five suburbs with highest crime rate.**

# %%
Boston.sort_values(by=['crim'], ascending=False).head()
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#      ptratio       b  lstat  medv
# 380     20.2  396.90  17.21  10.4
# 418     20.2   16.45  20.62   8.8
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0

# %% [markdown]
# **Five suburbs with highest tax rate.**

# %%
Boston.sort_values(by=['tax'], ascending=False).head()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
#
#           b  lstat  medv
# 492  396.90  13.35  20.1
# 491  390.11  18.07  13.6
# 490  318.43  29.68   8.1
# 489  344.05  23.97   7.0
# 488  395.09  18.06  15.2

# %% [markdown]
# **Five suburbs with highest pupil-teacher ratio.**

# %%
Boston.sort_values(by=['ptratio'], ascending=False).head()
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# 135  0.55778   0.0  21.89     0  0.624  6.335  98.2   2.1107    4  437
# 127  0.25915   0.0  21.89     0  0.624  5.693  96.0   1.7883    4  437
# 136  0.32264   0.0  21.89     0  0.624  5.942  93.5   1.9669    4  437
#
#      ptratio       b  lstat  medv
# 354     22.0  382.80   8.05  18.2
# 355     22.0  376.04   5.57  20.6
# 135     21.2  394.67  16.96  18.1
# 127     21.2  392.11  17.19  16.2
# 136     21.2  378.25  16.90  17.4

# %% [markdown]
# **Max, Min, Ranges of predictors.**

# %%
maxes = [np.max(Boston[column]) for column in Boston.columns]
mins = [np.min(Boston[column]) for column in Boston.columns]
ranges = [np.max(Boston[column]) - np.min(Boston[column]) for column in Boston.columns]

# %%
d = {'Max': maxes, 'Min': mins, 'Range': ranges}
measuresdf = pd.DataFrame(d, index=Boston.columns)

# %%
measuresdf
# Out:
#               Max        Min      Range
# crim      88.9762    0.00632   88.96988
# zn       100.0000    0.00000  100.00000
# indus     27.7400    0.46000   27.28000
# chas       1.0000    0.00000    1.00000
# nox        0.8710    0.38500    0.48600
# rm         8.7800    3.56100    5.21900
# age      100.0000    2.90000   97.10000
# dis       12.1265    1.12960   10.99690
# rad       24.0000    1.00000   23.00000
# tax      711.0000  187.00000  524.00000
# ptratio   22.0000   12.60000    9.40000
# b        396.9000    0.32000  396.58000
# lstat     37.9700    1.73000   36.24000
# medv      50.0000    5.00000   45.00000

# %% [markdown]
# ## Part (f)
# **Number of suburbs which bound the Charles river.**

# %%
Boston['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %% [markdown]
# We see that 35 suburbs bound the Charles river.

# %% [markdown]
# ## Part (g)
# **Median pupil-teacher ratio.**

# %%
np.median(Boston['ptratio'])
# Out:
# 19.05

# %% [markdown]
# We see the median pupil-teacher ratio is 19.05

# %% [markdown]
# ## Part (h)
# **Two suburbs with lowest median value of owner-occupied homes. Values of associated predictors.**

# %%
Boston.sort_values(by=['medv']).iloc[0:2]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio       b  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %% [markdown]
# For these two suburbs we see that crim is high, zn is low, indus is high, they do not bound the Charles River, nox is high, rm is low, age is high, dis is low, rad is high, tax is high, ptratio is high, b is high, lstat is high.
#
# Conclusion is high crime rate, lots of industry, bad air quality, homes with few rooms, old homes, close proximity to employment centers, high tax rate, high pupil-teacher ratio, high b, and high low status of population all pull the median value of owner-occupied homes down.

# %% [markdown]
# ## Part (i)
# **Number of suburbs averaging more than seven rooms per dwelling, more than eight rooms per dwelling.**

# %%
len(Boston.loc[Boston['rm'] > 7])
# Out:
# 64

# %% [markdown]
# We see there are 64 suburbs averaging more than seven rooms per dwelling.

# %%
len(Boston.loc[Boston['rm'] > 8])
# Out:
# 13

# %% [markdown]
# We see there are 13 suburbs averaging more than eight rooms per dwelling.

# %%
Boston.loc[Boston['rm'] > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# Suburbs averaging more than eight rooms per dwelling tend to have low crime rate, moderate to low proportion of non-retail business acres, do not bound Charles River, moderate nitrogen oxide concentration, moderately high proportion of owner-occupied units built prior to 1940, low distance to employment centers, moderately low accessibility to radial highways, low tax rate, moderate pupil-teacher ratio, high b, low lower status of population by percent, high median value of owner-occupied homes.
